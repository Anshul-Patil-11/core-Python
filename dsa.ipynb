# %%
list = [13,51,54,12,67,23,32,72]

list.sort(reverse=True)

print(list)

num = 13

while True:
    left = list[0]
    right = list[-1]
    if <num:
# Out:
# [72, 67, 54, 51, 32, 23, 13, 12]

# %%
# Create an algorithm to find the lowest value in a list:

list = [13,51,54,12,67,23,32,72]

min = list[0]
for i in list:
    if min > i:
        min = i

print(min)
# Out:
# 12

# %% [markdown]
# ## Stacks

# %%
# Stacks

stack = []

stack.append([4,5,6])
stack.extend([4,5,6])
stack.append(5)

print(stack)

pop = stack.pop()
pop = stack.pop()
pop = stack.pop()
pop = stack.pop()
pop = stack.pop()

print('Popped', stack)

isEmpty = not bool(stack)
print(isEmpty)
# Out:
# [[4, 5, 6], 4, 5, 6, 5]
# Popped []
# True

# %%
class Stack:
    def __init__(self):
        self.stack = []
    
    def push(self, element):
        self.stack.append(element)
    
    def pop(self):
        if self.isEmpty():
            return 'Stack is Empty'
        return self.stack.pop()
    
    def peek(self):
        if self.isEmpty():
            return 'Stack is Empty'
        return self.stack[-1]
    
    def isEmpty(self):
        return not bool(self.stack)
    
    def size(self):
        return len(self.stack)
    

myStack = Stack()

myStack.push('A')
myStack.push('B')
myStack.push('C')
myStack.push('D')

print('Stack', myStack.stack)
print("Pop: ", myStack.pop())
print("Stack after Pop: ", myStack.stack)
print("Peek: ", myStack.peek())
print("isEmpty: ", myStack.isEmpty())
print("Size: ", myStack.size())
# Out:
# Stack ['A', 'B', 'C', 'D']
# Pop:  D
# Stack after Pop:  ['A', 'B', 'C']
# Peek:  C
# isEmpty:  False
# Size:  3

# %%
# Stack using Linked List

class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self):
        self.head = None
        self.size = 0
    
    def push(self, value):
        newNode = Node(value)
        if self.head:
            newNode.next = self.head
        self.head = newNode
        self.size+=1

    def pop(self):
        if self.size == 0:
            return 'Stack is empty'
        popped = self.head
        self.head = self.head.next
        self.size -= 1
        return popped.value
    
    def peek(self):
        if self.size == 0:
            return 'Stack is empty'
        return self.head.value
    
    def isEmpty(self):
        return self.size==0
    
    def stackSize(self):
        return self.size
    
    def traverseAndPrint(self):
        currentNode = self.head
        while currentNode.next!=None:
            print(currentNode.value,"->")
            currentNode = currentNode.next
        print(currentNode.value)

myStack = Stack()
myStack.push('A')
myStack.push('B')
myStack.push('C')

print("LinkedList: ", end="")
myStack.traverseAndPrint()
print("Peek: ", myStack.peek())
print("Pop: ", myStack.pop())
print("LinkedList after Pop: ", end="")
myStack.traverseAndPrint()
print("isEmpty: ", myStack.isEmpty())
print("Size: ", myStack.stackSize())
# Out:
# LinkedList: C ->
# B ->
# A
# Peek:  C
# Pop:  C
# LinkedList after Pop: B ->
# A
# isEmpty:  False
# Size:  2

# %% [markdown]
# ## Queues

# %%
# Python List as a Queue

x = [5, 6, 2, 9, 3, 8, 4, 2]

def enqueue(item):
    x.append(item)
    print(item," appended\nNew List: ",x)

enqueue(12)
enqueue(132)
enqueue(11)
enqueue(1)

def dequeue():
    popped = x.pop(0)
    print(f"\npopped {popped}, Queue: {x}")

dequeue()
dequeue()

def peek():
    print(x[0])

def isEmpty():
    return len(x)==0

def size(array):
    return len(array)

peek()

print(isEmpty(), size(x))
# Out:
# 12  appended
# New List:  [5, 6, 2, 9, 3, 8, 4, 2, 12]
# 132  appended
# New List:  [5, 6, 2, 9, 3, 8, 4, 2, 12, 132]
# 11  appended
# New List:  [5, 6, 2, 9, 3, 8, 4, 2, 12, 132, 11]
# 1  appended
# New List:  [5, 6, 2, 9, 3, 8, 4, 2, 12, 132, 11, 1]
#
# popped 5, Queue: [6, 2, 9, 3, 8, 4, 2, 12, 132, 11, 1]
#
# popped 6, Queue: [2, 9, 3, 8, 4, 2, 12, 132, 11, 1]
# 2
# False 10

# %%
# Implementing a Queue class

class Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, value):
        self.queue.append(value)
    
    def dequeue(self):
        if len(self.queue):
            popped = self.queue.pop(0)
            return popped
        print("Queue is Empty")
    
    def peek(self):
        if len(self.queue)==0:
            print("Queue is Empty")
        print(self.queue[0])
    
    def isEmpty(self):
        print(len(self.queue)==0)
    
    def Size(self):
        print("Size: ", len(self.queue))

q = Queue()
print(q.queue)

q.enqueue(4)
q.enqueue(1)
q.enqueue(6)
q.enqueue(8)
q.enqueue(2)

print(q.queue)

q.dequeue()
print(q.queue)
# q.dequeue()
# print(q.queue)
# q.dequeue()
# print(q.queue)
# q.dequeue()
# print(q.queue)
# q.dequeue()
# print(q.queue)
# q.dequeue()
# print(q.queue)

q.peek()

q.isEmpty()

q.Size()
# Out:
# []
# [4, 1, 6, 8, 2]
# [1, 6, 8, 2]
# 1
# False
# Size:  4

# %%
# Queue Implementation using Linked List

class Node:
    def __init__(self,value):
        self.value = value
        self.next = None

class Queue:
    def __init__(self):
        self.head = None
        self.tail = None
        self.size = 0

    def enqueue(self,value):
        newNode = Node(value)
        if self.head==None:
            self.head = newNode
        else:
            self.tail.next = newNode
        self.tail = newNode
        self.size+=1
        
    def dequeue(self):
        if self.head:
            popped = self.head.value
            print("popped", popped)
            self.head=self.head.next
            self.size-=1
        else:
            print("Queue is Empty")

    def traverseAndPrint(self):
        if self.head:
            t = self.head
            while t.next:
                print(t.value, "->", end=" ")
                t = t.next
            print(t.value)
        else:
            print("Queue is Empty")
    
    def peek(self):
        if self.size==0:
            print("Queue is Empty")
        print(self.head.value)

    def isEmpty(self):
        return self.size==0
    
    def Size(self):
        print("Size: ", self.size)

      
q = Queue()
q.traverseAndPrint()
q.enqueue(44)
q.traverseAndPrint()
q.enqueue(1)
q.traverseAndPrint()
q.enqueue(2)
q.traverseAndPrint()
q.enqueue(39)
q.traverseAndPrint()
q.enqueue(6)
q.traverseAndPrint()
q.enqueue(3)
q.traverseAndPrint()

q.dequeue()
q.traverseAndPrint()
q.dequeue()
q.traverseAndPrint()
q.dequeue()

q.peek()
q.isEmpty()
q.Size()

q.traverseAndPrint()
q.dequeue()
q.traverseAndPrint()
q.dequeue()
q.traverseAndPrint()
q.dequeue()
q.traverseAndPrint()
q.dequeue()
# Out:
# Queue is Empty
# 44
# 44 -> 1
# 44 -> 1 -> 2
# 44 -> 1 -> 2 -> 39
# 44 -> 1 -> 2 -> 39 -> 6
# 44 -> 1 -> 2 -> 39 -> 6 -> 3
# popped 44
# 1 -> 2 -> 39 -> 6 -> 3
# popped 1
# 2 -> 39 -> 6 -> 3
# popped 2
# 39
# Size:  3
# 39 -> 6 -> 3
# popped 39
# 6 -> 3
# popped 6
# 3
# popped 3
# Queue is Empty
# Queue is Empty

# %% [markdown]
# ## Linked List

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None

# Function to Traverse Linked List 

def traverseAndPrint(head):
    if head:
        currentNode = head
        while currentNode.next:
            print(currentNode.value, end =" -> ")
            currentNode = currentNode.next
        print(currentNode.value)
    else:
        print("Empty Linked List!")

node1 = Node(4)
node2 = Node(8)
node3 = Node(5)
node4 = Node(44)
node5 = Node(89)
        
node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

traverseAndPrint(node1)

# To find lowest value

def findLowestValue(head):
    if head:
        lowest = head.value
        currentNode=head.next
        while currentNode:
            if lowest>currentNode.value:
                lowest=currentNode.value
            currentNode = currentNode.next
        print(f"The lowest Value is {lowest}")
    else:
        print("Empty Linked List!")

findLowestValue(node1)

# Delete a Node in Linked List

def deleteSpecificNode(head, node_to_delete):
    if head:
        if head == node_to_delete:
            return head.next
        currentNode = head
        while currentNode:
            if currentNode.next==node_to_delete:
                currentNode.next=node_to_delete.next
            currentNode = currentNode.next
        return head
    else:
        print("Empty Linked List!")

# Delete node4
print("Deleting Node 5:")
node1 = deleteSpecificNode(node1, node5)

traverseAndPrint(node1)

def insertNodeAtPosition(head, newNode, position):
    placement_after = position - 1
    if placement_after == 0:
        newNode.next = head
        head = newNode
        return head
    currentNode = head
    while True:
        if placement_after == 1:
            break
        placement_after-=1
        currentNode = currentNode.next
    newNode.next = currentNode.next
    currentNode.next = newNode
    return head

print("Original list:")
traverseAndPrint(node1)

# Insert a new node with value 97 at position 2
newNode = Node(97)
node1 = insertNodeAtPosition(node1, newNode, 5)

print("\nAfter inserting:",newNode.value," at position")
traverseAndPrint(node1)
# Out:
# 4 -> 8 -> 5 -> 44 -> 89
# The lowest Value is 4
# Deleting Node 5:
# 4 -> 8 -> 5 -> 44
# Original list:
# 4 -> 8 -> 5 -> 44
#
# After inserting: 97  at position
# 4 -> 8 -> 5 -> 44 -> 97

# %% [markdown]
# ## Hash Tables
